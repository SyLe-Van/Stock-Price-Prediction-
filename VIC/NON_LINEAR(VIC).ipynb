# %%
#Import libraries
import numpy.polynomial.polynomial as poly
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/VIC Historical Data (3).csv")
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     11/30/2022  69.600  69.500  70.200  68.000    3.23M    0.29%
# 1     11/29/2022  69.400  65.000  69.400  64.200    3.56M    6.77%
# 2     11/28/2022  65.000  66.500  67.100  65.000    3.25M    0.00%
# 3     11/25/2022  65.000  63.000  65.000  62.600    2.29M    6.56%
# 4     11/24/2022  61.000  60.000  62.100  60.000    1.14M    2.18%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1747   12/4/2015  31.109  31.329  31.550  31.035  767.62K   -1.17%
# 1748   12/3/2015  31.476  31.329  31.550  31.256  567.97K    0.47%
# 1749   12/2/2015  31.329  31.623  31.844  31.329  984.00K   -0.47%
# 1750   12/1/2015  31.476  31.550  31.623  31.403  355.81K    0.00%
# 1751  11/30/2015  31.476  31.109  31.476  31.035    1.28M    0.47%
#
# [1752 rows x 7 columns]

# %%
#get infomation data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1752 non-null   object
#  1   Price     1752 non-null   float64
#  2   Open      1752 non-null   float64
#  3   High      1752 non-null   float64
#  4   Low       1752 non-null   float64
#  5   Vol.      1752 non-null   object
#  6   Change %  1752 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 95.9+ KB

# %%
#Show description data
df.describe()
# Out:
#              Price         Open         High          Low
# count  1752.000000  1752.000000  1752.000000  1752.000000
# mean     76.568489    76.478716    77.395226    75.528217
# std      28.935213    28.929694    29.219089    28.603848
# min      29.417000    30.022000    30.520000    28.065000
# 25%      40.330000    40.144000    40.723250    39.345000
# 50%      83.672000    83.556000    84.889000    82.398500
# 75%     101.987250   101.653000   102.302750   100.445000
# max     128.000000   128.000000   129.689000   127.111000

# %%
#Create Time column has value is index
df['Time'] = np.arange(len(df.index))
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %  Time
# 0     11/30/2022  69.600  69.500  70.200  68.000    3.23M    0.29%     0
# 1     11/29/2022  69.400  65.000  69.400  64.200    3.56M    6.77%     1
# 2     11/28/2022  65.000  66.500  67.100  65.000    3.25M    0.00%     2
# 3     11/25/2022  65.000  63.000  65.000  62.600    2.29M    6.56%     3
# 4     11/24/2022  61.000  60.000  62.100  60.000    1.14M    2.18%     4
# ...          ...     ...     ...     ...     ...      ...      ...   ...
# 1747   12/4/2015  31.109  31.329  31.550  31.035  767.62K   -1.17%  1747
# 1748   12/3/2015  31.476  31.329  31.550  31.256  567.97K    0.47%  1748
# 1749   12/2/2015  31.329  31.623  31.844  31.329  984.00K   -0.47%  1749
# 1750   12/1/2015  31.476  31.550  31.623  31.403  355.81K    0.00%  1750
# 1751  11/30/2015  31.476  31.109  31.476  31.035    1.28M    0.47%  1751
#
# [1752 rows x 8 columns]

# %%
df['New_Time'] = pd.to_datetime(df.Date)
type(df['New_Time'])
# Out:
# pandas.core.series.Series

# %%
df.index = df['New_Time']
df
# Out:
#                   Date   Price    Open    High     Low     Vol. Change %  \
# New_Time
# 2022-11-30  11/30/2022  69.600  69.500  70.200  68.000    3.23M    0.29%
# 2022-11-29  11/29/2022  69.400  65.000  69.400  64.200    3.56M    6.77%
# 2022-11-28  11/28/2022  65.000  66.500  67.100  65.000    3.25M    0.00%
# 2022-11-25  11/25/2022  65.000  63.000  65.000  62.600    2.29M    6.56%
# 2022-11-24  11/24/2022  61.000  60.000  62.100  60.000    1.14M    2.18%
# ...                ...     ...     ...     ...     ...      ...      ...
# 2015-12-04   12/4/2015  31.109  31.329  31.550  31.035  767.62K   -1.17%
# 2015-12-03   12/3/2015  31.476  31.329  31.550  31.256  567.97K    0.47%
# 2015-12-02   12/2/2015  31.329  31.623  31.844  31.329  984.00K   -0.47%
# 2015-12-01   12/1/2015  31.476  31.550  31.623  31.403  355.81K    0.00%
# 2015-11-30  11/30/2015  31.476  31.109  31.476  31.035    1.28M    0.47%
#
#             Time   New_Time
# New_Time
# 2022-11-30     0 2022-11-30
# 2022-11-29     1 2022-11-29
# 2022-11-28     2 2022-11-28
# 2022-11-25     3 2022-11-25
# 2022-11-24     4 2022-11-24
# ...          ...        ...
# 2015-12-04  1747 2015-12-04
# 2015-12-03  1748 2015-12-03
# 2015-12-02  1749 2015-12-02
# 2015-12-01  1750 2015-12-01
# 2015-11-30  1751 2015-11-30
#
# [1752 rows x 9 columns]

# %%
##visualization FPT stock price from 2015 to 2022
df.plot(x = 'Date', y = 'Price', figsize = (12,5))

# %%
x = np.array(df.Time, dtype = float)
y = np.array(df.Price, dtype = float)
z = [1752,1753,1754,1755,1756,1757,1758,1759,1760,1761,1762,1763,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781]

# %%
no_of_days = 30
future_day = pd.date_range(start= "12/1/2022",end = "12/30/2022")

# %%
coefs = poly.polyfit(x, y, 9)
x_new = np.linspace(x[0], x[-1] + no_of_days, num = len(x) + no_of_days)
fit = poly.polyval(x_new, coefs)
pred = poly.polyval(z, coefs)
predictions = pd.DataFrame(future_day ,pred)
print(predictions)
# Out:
#                    0
# 33.480918 2022-12-01
# 33.590209 2022-12-02
# 33.705539 2022-12-03
# 33.827049 2022-12-04
# 33.954885 2022-12-05
# 34.089194 2022-12-06
# 34.230124 2022-12-07
# 34.377828 2022-12-08
# 34.532458 2022-12-09
# 34.694169 2022-12-10
# 34.863119 2022-12-11
# 35.039466 2022-12-12
# 35.223373 2022-12-13
# 35.415003 2022-12-14
# 35.614522 2022-12-15
# 35.822098 2022-12-16
# 36.037901 2022-12-17
# 36.262103 2022-12-18
# 36.494879 2022-12-19
# 36.736406 2022-12-20
# 36.986862 2022-12-21
# 37.246430 2022-12-22
# 37.515293 2022-12-23
# 37.793637 2022-12-24
# 38.081651 2022-12-25
# 38.379525 2022-12-26
# 38.687452 2022-12-27
# 39.005628 2022-12-28
# 39.334251 2022-12-29
# 39.673521 2022-12-30

# %%
new_time2 = df.index.append(future_day)
new_time2
# Out:
# DatetimeIndex(['2022-11-30', '2022-11-29', '2022-11-28', '2022-11-25',
#                '2022-11-24', '2022-11-23', '2022-11-22', '2022-11-21',
#                '2022-11-18', '2022-11-17',
#                ...
#                '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#                '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', length=1782, freq=None)

# %%
plt.plot(figsize = (18,5))
plt.plot(df['New_Time'],y, 'blue', label = "Original price")
plt.plot(new_time2, fit, 'black', label = "Fitted price")
plt.plot(future_day, pred, 'red', label = "Prediction price")
plt.legend(loc = 'upper left')
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

fit = fit[30:].reshape(1752,)

mape = mean_absolute_percentage_error(y, fit)
mse = mean_squared_error(y, fit)
rmse = np.sqrt(mse)


print(f"MAPE: {mape * 100:.2f}%")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAPE: 7.25%
# RMSE: 7.79
