# %%
#Import libraries
import numpy.polynomial.polynomial as poly
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Get the data
df = pd.read_csv("VCB3.csv")
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     11/30/2015  23.115  23.815  23.869  23.115    1.68M   -3.16%
# 1      12/1/2015  22.684  23.115  23.384  22.630    1.52M   -1.86%
# 2      12/2/2015  22.738  22.684  23.007  22.630    2.99M    0.24%
# 3      12/3/2015  22.953  22.630  23.223  22.630    1.70M    0.95%
# 4      12/4/2015  22.792  23.115  23.115  22.684  833.53K   -0.70%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1747  11/24/2022  73.000  73.500  74.000  72.500    1.08M   -0.68%
# 1748  11/25/2022  73.100  73.100  73.600  72.800    1.68M    0.14%
# 1749  11/28/2022  76.700  74.500  77.000  73.800    1.34M    4.92%
# 1750  11/29/2022  79.800  76.000  79.800  76.000    1.71M    4.04%
# 1751  11/30/2022  81.000  80.300  81.000  77.000    1.32M    1.50%
#
# [1752 rows x 7 columns]

# %%
#get infomation data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1752 non-null   object
#  1   Price     1752 non-null   float64
#  2   Open      1752 non-null   float64
#  3   High      1752 non-null   float64
#  4   Low       1752 non-null   float64
#  5   Vol.      1752 non-null   object
#  6   Change %  1752 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 95.9+ KB

# %%
#Show description data
df.describe()
# Out:
#              Price         Open         High          Low
# count  1752.000000  1752.000000  1752.000000  1752.000000
# mean     53.197012    53.157417    53.816959    52.516457
# std      20.532650    20.515369    20.751908    20.236389
# min      20.798000    20.798000    21.552000    20.475000
# 25%      29.154750    29.164000    29.560500    28.826000
# 50%      53.294000    53.072000    54.174500    52.142000
# 75%      73.412500    73.548000    74.305500    72.500000
# max      95.800000    95.800000    96.000000    92.600000

# %%
#Create Time column has value is index
df['Time'] = np.arange(len(df.index))
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %  Time
# 0     11/30/2015  23.115  23.815  23.869  23.115    1.68M   -3.16%     0
# 1      12/1/2015  22.684  23.115  23.384  22.630    1.52M   -1.86%     1
# 2      12/2/2015  22.738  22.684  23.007  22.630    2.99M    0.24%     2
# 3      12/3/2015  22.953  22.630  23.223  22.630    1.70M    0.95%     3
# 4      12/4/2015  22.792  23.115  23.115  22.684  833.53K   -0.70%     4
# ...          ...     ...     ...     ...     ...      ...      ...   ...
# 1747  11/24/2022  73.000  73.500  74.000  72.500    1.08M   -0.68%  1747
# 1748  11/25/2022  73.100  73.100  73.600  72.800    1.68M    0.14%  1748
# 1749  11/28/2022  76.700  74.500  77.000  73.800    1.34M    4.92%  1749
# 1750  11/29/2022  79.800  76.000  79.800  76.000    1.71M    4.04%  1750
# 1751  11/30/2022  81.000  80.300  81.000  77.000    1.32M    1.50%  1751
#
# [1752 rows x 8 columns]

# %%
#
df['new_time'] = pd.to_datetime(df.Date)
type(df['new_time'])
# Out:
# pandas.core.series.Series

# %%
df.index = df['new_time']
df
# Out:
#                   Date   Price    Open    High     Low     Vol. Change %  \
# new_time
# 2015-11-30  11/30/2015  23.115  23.815  23.869  23.115    1.68M   -3.16%
# 2015-12-01   12/1/2015  22.684  23.115  23.384  22.630    1.52M   -1.86%
# 2015-12-02   12/2/2015  22.738  22.684  23.007  22.630    2.99M    0.24%
# 2015-12-03   12/3/2015  22.953  22.630  23.223  22.630    1.70M    0.95%
# 2015-12-04   12/4/2015  22.792  23.115  23.115  22.684  833.53K   -0.70%
# ...                ...     ...     ...     ...     ...      ...      ...
# 2022-11-24  11/24/2022  73.000  73.500  74.000  72.500    1.08M   -0.68%
# 2022-11-25  11/25/2022  73.100  73.100  73.600  72.800    1.68M    0.14%
# 2022-11-28  11/28/2022  76.700  74.500  77.000  73.800    1.34M    4.92%
# 2022-11-29  11/29/2022  79.800  76.000  79.800  76.000    1.71M    4.04%
# 2022-11-30  11/30/2022  81.000  80.300  81.000  77.000    1.32M    1.50%
#
#             Time   new_time
# new_time
# 2015-11-30     0 2015-11-30
# 2015-12-01     1 2015-12-01
# 2015-12-02     2 2015-12-02
# 2015-12-03     3 2015-12-03
# 2015-12-04     4 2015-12-04
# ...          ...        ...
# 2022-11-24  1747 2022-11-24
# 2022-11-25  1748 2022-11-25
# 2022-11-28  1749 2022-11-28
# 2022-11-29  1750 2022-11-29
# 2022-11-30  1751 2022-11-30
#
# [1752 rows x 9 columns]

# %%
##visualization FPT stock price from 2015 to 2022
df.plot(x = 'Time', y = 'Price', figsize = (12,5))

# %%
x = np.array(df.Time, dtype = float)
y = np.array(df.Price, dtype = float)
z = [1752,1753,1754,1755,1756,1757,1758,1759,1760,1761,1762,1763,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781]

# %%
no_of_days = 30
future_day = pd.date_range(start= "12/1/2022",end = "12/30/2022")

# %%
coefs = poly.polyfit(x, y, 1)
x_new = np.linspace(x[0], x[-1] + no_of_days, num = len(x) + no_of_days)
fit = poly.polyval(x_new, coefs)
pred = poly.polyval(z, coefs)
predictions = pd.DataFrame(future_day ,pred)
print(predictions)
# Out:
#                    0
# 87.184451 2022-12-01
# 87.223227 2022-12-02
# 87.262003 2022-12-03
# 87.300780 2022-12-04
# 87.339556 2022-12-05
# 87.378332 2022-12-06
# 87.417109 2022-12-07
# 87.455885 2022-12-08
# 87.494661 2022-12-09
# 87.533438 2022-12-10
# 87.572214 2022-12-11
# 87.610990 2022-12-12
# 87.649767 2022-12-13
# 87.688543 2022-12-14
# 87.727319 2022-12-15
# 87.766095 2022-12-16
# 87.804872 2022-12-17
# 87.843648 2022-12-18
# 87.882424 2022-12-19
# 87.921201 2022-12-20
# 87.959977 2022-12-21
# 87.998753 2022-12-22
# 88.037530 2022-12-23
# 88.076306 2022-12-24
# 88.115082 2022-12-25
# 88.153859 2022-12-26
# 88.192635 2022-12-27
# 88.231411 2022-12-28
# 88.270188 2022-12-29
# 88.308964 2022-12-30

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

fit = fit[30:].reshape(1752,)

mape = mean_absolute_percentage_error(y, fit)
mse = mean_squared_error(y, fit)
rmse = np.sqrt(mse)


print(f"MAPE: {mape * 100:.2f}%")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAPE: 10.00%
# RMSE: 6.17

# %%
df['new_time']
# Out:
# new_time
# 2015-11-30   2015-11-30
# 2015-12-01   2015-12-01
# 2015-12-02   2015-12-02
# 2015-12-03   2015-12-03
# 2015-12-04   2015-12-04
#                 ...
# 2022-11-24   2022-11-24
# 2022-11-25   2022-11-25
# 2022-11-28   2022-11-28
# 2022-11-29   2022-11-29
# 2022-11-30   2022-11-30
# Name: new_time, Length: 1752, dtype: datetime64[ns]

# %%
plt.plot(figsize = (12,5))
plt.plot(df['new_time'],y, 'blue', label = "Original price")
plt.plot(df['new_time'], fit, 'black', label = "Fitted price")
plt.plot(future_day, pred, 'red', label = "Prediction price")
plt.legend(loc = 'upper left')
plt.show()
