# %%
#Import libraries
import numpy.polynomial.polynomial as poly
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("VCB3.csv")
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     2015-11-30  23.115  23.815  23.869  23.115    1.68M   -3.16%
# 1     2015-12-01  22.684  23.115  23.384  22.630    1.52M   -1.86%
# 2     2015-12-02  22.738  22.684  23.007  22.630    2.99M    0.24%
# 3     2015-12-03  22.953  22.630  23.223  22.630    1.70M    0.95%
# 4     2015-12-04  22.792  23.115  23.115  22.684  833.53K   -0.70%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1747  2022-11-24  73.000  73.500  74.000  72.500    1.08M   -0.68%
# 1748  2022-11-25  73.100  73.100  73.600  72.800    1.68M    0.14%
# 1749  2022-11-28  76.700  74.500  77.000  73.800    1.34M    4.92%
# 1750  2022-11-29  79.800  76.000  79.800  76.000    1.71M    4.04%
# 1751  2022-11-30  81.000  80.300  81.000  77.000    1.32M    1.50%
#
# [1752 rows x 7 columns]

# %%
#get infomation data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1752 entries, 0 to 1751
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1752 non-null   object
#  1   Price     1752 non-null   float64
#  2   Open      1752 non-null   float64
#  3   High      1752 non-null   float64
#  4   Low       1752 non-null   float64
#  5   Vol.      1752 non-null   object
#  6   Change %  1752 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 95.9+ KB

# %%
#Show description data
df.describe()
# Out:
#              Price         Open         High          Low
# count  1752.000000  1752.000000  1752.000000  1752.000000
# mean     53.197012    53.157417    53.816959    52.516457
# std      20.532650    20.515369    20.751908    20.236389
# min      20.798000    20.798000    21.552000    20.475000
# 25%      29.154750    29.164000    29.560500    28.826000
# 50%      53.294000    53.072000    54.174500    52.142000
# 75%      73.412500    73.548000    74.305500    72.500000
# max      95.800000    95.800000    96.000000    92.600000

# %%
#Create Time column has value is index
df['Time'] = np.arange(len(df.index))
df
# Out:
#             Date   Price    Open    High     Low     Vol. Change %  Time
# 0     2015-11-30  23.115  23.815  23.869  23.115    1.68M   -3.16%     0
# 1     2015-12-01  22.684  23.115  23.384  22.630    1.52M   -1.86%     1
# 2     2015-12-02  22.738  22.684  23.007  22.630    2.99M    0.24%     2
# 3     2015-12-03  22.953  22.630  23.223  22.630    1.70M    0.95%     3
# 4     2015-12-04  22.792  23.115  23.115  22.684  833.53K   -0.70%     4
# ...          ...     ...     ...     ...     ...      ...      ...   ...
# 1747  2022-11-24  73.000  73.500  74.000  72.500    1.08M   -0.68%  1747
# 1748  2022-11-25  73.100  73.100  73.600  72.800    1.68M    0.14%  1748
# 1749  2022-11-28  76.700  74.500  77.000  73.800    1.34M    4.92%  1749
# 1750  2022-11-29  79.800  76.000  79.800  76.000    1.71M    4.04%  1750
# 1751  2022-11-30  81.000  80.300  81.000  77.000    1.32M    1.50%  1751
#
# [1752 rows x 8 columns]

# %%
df['New_Time'] = pd.to_datetime(df.Date)
type(df['New_Time'])
# Out:
# pandas.core.series.Series

# %%
df.index = df['New_Time']
df
# Out:
#                   Date   Price    Open    High     Low     Vol. Change %  \
# New_Time
# 2015-11-30  2015-11-30  23.115  23.815  23.869  23.115    1.68M   -3.16%
# 2015-12-01  2015-12-01  22.684  23.115  23.384  22.630    1.52M   -1.86%
# 2015-12-02  2015-12-02  22.738  22.684  23.007  22.630    2.99M    0.24%
# 2015-12-03  2015-12-03  22.953  22.630  23.223  22.630    1.70M    0.95%
# 2015-12-04  2015-12-04  22.792  23.115  23.115  22.684  833.53K   -0.70%
# ...                ...     ...     ...     ...     ...      ...      ...
# 2022-11-24  2022-11-24  73.000  73.500  74.000  72.500    1.08M   -0.68%
# 2022-11-25  2022-11-25  73.100  73.100  73.600  72.800    1.68M    0.14%
# 2022-11-28  2022-11-28  76.700  74.500  77.000  73.800    1.34M    4.92%
# 2022-11-29  2022-11-29  79.800  76.000  79.800  76.000    1.71M    4.04%
# 2022-11-30  2022-11-30  81.000  80.300  81.000  77.000    1.32M    1.50%
#
#             Time   New_Time
# New_Time
# 2015-11-30     0 2015-11-30
# 2015-12-01     1 2015-12-01
# 2015-12-02     2 2015-12-02
# 2015-12-03     3 2015-12-03
# 2015-12-04     4 2015-12-04
# ...          ...        ...
# 2022-11-24  1747 2022-11-24
# 2022-11-25  1748 2022-11-25
# 2022-11-28  1749 2022-11-28
# 2022-11-29  1750 2022-11-29
# 2022-11-30  1751 2022-11-30
#
# [1752 rows x 9 columns]

# %%
##visualization FPT stock price from 2015 to 2022
df.plot(x = 'Date', y = 'Price', figsize = (12,5))

# %%
x = np.array(df.Time, dtype = float)
y = np.array(df.Price, dtype = float)
z = [1752,1753,1754,1755,1756,1757,1758,1759,1760,1761,1762,1763,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781]

# %%
no_of_days = 30
future_day = pd.date_range(start= "12/1/2022",end = "12/30/2022")

# %%
coefs = poly.polyfit(x, y, 9)
x_new = np.linspace(x[0], x[-1] + no_of_days, num = len(x) + no_of_days)
fit = poly.polyval(x_new, coefs)
pred = poly.polyval(z, coefs)
predictions = pd.DataFrame(future_day ,pred)
print(predictions)
# Out:
#                    0
# 72.628735 2022-12-01
# 72.599684 2022-12-02
# 72.571743 2022-12-03
# 72.544937 2022-12-04
# 72.519290 2022-12-05
# 72.494831 2022-12-06
# 72.471584 2022-12-07
# 72.449576 2022-12-08
# 72.428835 2022-12-09
# 72.409386 2022-12-10
# 72.391259 2022-12-11
# 72.374481 2022-12-12
# 72.359079 2022-12-13
# 72.345082 2022-12-14
# 72.332519 2022-12-15
# 72.321420 2022-12-16
# 72.311812 2022-12-17
# 72.303727 2022-12-18
# 72.297193 2022-12-19
# 72.292242 2022-12-20
# 72.288904 2022-12-21
# 72.287210 2022-12-22
# 72.287190 2022-12-23
# 72.288878 2022-12-24
# 72.292305 2022-12-25
# 72.297503 2022-12-26
# 72.304504 2022-12-27
# 72.313342 2022-12-28
# 72.324051 2022-12-29
# 72.336663 2022-12-30

# %%
new_time2 = df.index.append(future_day)
new_time2
# Out:
# DatetimeIndex(['2015-11-30', '2015-12-01', '2015-12-02', '2015-12-03',
#                '2015-12-04', '2015-12-07', '2015-12-08', '2015-12-09',
#                '2015-12-10', '2015-12-11',
#                ...
#                '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#                '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28',
#                '2022-12-29', '2022-12-30'],
#               dtype='datetime64[ns]', length=1782, freq=None)

# %%
plt.plot(figsize = (18,5))
plt.plot(df['New_Time'],y, 'blue', label = "Original price")
plt.plot(new_time2, fit, 'black', label = "Fitted price")
plt.plot(future_day, pred, 'red', label = "Prediction price")
plt.legend(loc = 'upper left')
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

fit = fit[30:].reshape(1752,)

mape = mean_absolute_percentage_error(y, fit)
mse = mean_squared_error(y, fit)
rmse = np.sqrt(mse)


print(f"MAPE: {mape * 100:.2f}%")
print(f"RMSE: {rmse:.2f}")
# Out:
# MAPE: 8.47%
# RMSE: 5.14
